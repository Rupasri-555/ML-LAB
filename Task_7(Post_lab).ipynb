# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupasri-555/ML-LAB/blob/main/Task_7(Post_lab).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Load Titanic dataset directly
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

# Select features
X = data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = data['Survived']

# Convert Sex into numbers
X['Sex'] = X['Sex'].map({'male': 0, 'female': 1})

# Handle missing values
X['Age'] = X['Age'].fillna(X['Age'].median())

# K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Random Forest model
model = RandomForestClassifier(random_state=42)

# Parameters for Grid Search
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'min_samples_split': [2, 5]
}

# Grid Search with K-Fold
grid_search = GridSearchCV(
    model,
    param_grid,
    cv=kf,
    scoring='accuracy'
)

# Train
grid_search.fit(X, y)

# Results
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Accuracy:")
print(grid_search.best_score_)
# Out:
# /tmp/ipykernel_492/3846768127.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sex'] = X['Sex'].map({'male': 0, 'female': 1})
# /tmp/ipykernel_492/3846768127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Age'] = X['Age'].fillna(X['Age'].median())
# Best Parameters:
# {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 50}
#
# Best Accuracy:
# 0.8282970309459545
