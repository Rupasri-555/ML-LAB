# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupasri-555/ML-LAB/blob/main/TASK_8(IN_LAB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Load Pima Indians Diabetes dataset
pima_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
pima_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
pima_df = pd.read_csv(pima_url, header=None, names=pima_cols)

# Prevent copy warnings using an explicit copy
X_pima = pima_df[pima_cols[:-1]].copy()
y_pima = pima_df['Outcome']

# Mark invalid zeros as NaN placeholders for imputation
cols_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
X_pima[cols_to_impute] = X_pima[cols_to_impute].replace(0, np.nan)

# Impute and standardize
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X_pima)

scaler = StandardScaler()
X_pima_scaled = scaler.fit_transform(X_imputed)

# Stratified train-test split
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(
    X_pima_scaled, y_pima, test_size=0.20, stratify=y_pima, random_state=42
)

print("Preprocessed Pima dataset shapes:")
print(f"  Training set features: {X_train_p.shape} | Test set features: {X_test_p.shape}")
# Out:
# Preprocessed Pima dataset shapes:
#   Training set features: (614, 8) | Test set features: (154, 8)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Design baseline sequential model
ann_pima = Sequential([
    # Input layer + Hidden layer 1: 16 neurons with ReLU activation
    Dense(16, activation='relu', input_shape=(8,)),
    # Hidden layer 2: 8 neurons with ReLU activation
    Dense(8, activation='relu'),
    # Output layer: 1 neuron with Sigmoid activation for binary classification
    Dense(1, activation='sigmoid')
])

print("Sequential ANN Architecture established:")
ann_pima.summary()
# Out:
# Sequential ANN Architecture established:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the neural network model
ann_pima.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print("Neural network model compiled successfully.")
# Out:
# Neural network model compiled successfully.

# %%
# Fit model and collect training metrics
history_pima = ann_pima.fit(
    X_train_p,
    y_train_p,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)

print("\nModel training complete.")
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6069 - loss: 0.6803 - val_accuracy: 0.6504 - val_loss: 0.6782
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6843 - loss: 0.6425 - val_accuracy: 0.7154 - val_loss: 0.6348
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7251 - loss: 0.6058 - val_accuracy: 0.7236 - val_loss: 0.5916
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7373 - loss: 0.5668 - val_accuracy: 0.7480 - val_loss: 0.5474
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - loss: 0.5281 - val_accuracy: 0.7805 - val_loss: 0.5118
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7576 - loss: 0.5002 - val_accuracy: 0.7642 - val_loss: 0.4800
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.4804 - val_accuracy: 0.7886 - val_loss: 0.4626
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.4672 - val_accuracy: 0.7886 - val_loss: 0.4493
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7739 - loss: 0.4589 - val_accuracy: 0.8049 - val_loss: 0.4408
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7862 - loss: 0.4525 - val_accuracy: 0.8130 - val_loss: 0.4344
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7841 - loss: 0.4484 - val_accuracy: 0.8130 - val_loss: 0.4343
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7862 - loss: 0.4451 - val_accuracy: 0.8130 - val_loss: 0.4280
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4423 - val_accuracy: 0.8130 - val_loss: 0.4277
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7943 - loss: 0.4404 - val_accuracy: 0.8049 - val_loss: 0.4265
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4380 - val_accuracy: 0.8049 - val_loss: 0.4252
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4359 - val_accuracy: 0.8130 - val_loss: 0.4294
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7963 - loss: 0.4340 - val_accuracy: 0.8049 - val_loss: 0.4253
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4332 - val_accuracy: 0.8130 - val_loss: 0.4276
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4305 - val_accuracy: 0.8049 - val_loss: 0.4242
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4292 - val_accuracy: 0.8130 - val_loss: 0.4248
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.4269 - val_accuracy: 0.8130 - val_loss: 0.4237
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4265 - val_accuracy: 0.8130 - val_loss: 0.4274
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4246 - val_accuracy: 0.8130 - val_loss: 0.4262
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.4232 - val_accuracy: 0.8130 - val_loss: 0.4250
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.4218 - val_accuracy: 0.8130 - val_loss: 0.4247
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.4204 - val_accuracy: 0.8130 - val_loss: 0.4245
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.4195 - val_accuracy: 0.8130 - val_loss: 0.4241
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.4174 - val_accuracy: 0.8130 - val_loss: 0.4246
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4167 - val_accuracy: 0.8130 - val_loss: 0.4251
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4148 - val_accuracy: 0.8130 - val_loss: 0.4239
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4138 - val_accuracy: 0.8049 - val_loss: 0.4217
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4124 - val_accuracy: 0.8130 - val_loss: 0.4229
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4112 - val_accuracy: 0.8049 - val_loss: 0.4227
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4095 - val_accuracy: 0.8130 - val_loss: 0.4227
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.4086 - val_accuracy: 0.8130 - val_loss: 0.4257
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4077 - val_accuracy: 0.8049 - val_loss: 0.4227
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4058 - val_accuracy: 0.8049 - val_loss: 0.4229
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.4049 - val_accuracy: 0.8049 - val_loss: 0.4249
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.4033 - val_accuracy: 0.8130 - val_loss: 0.4230
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4029 - val_accuracy: 0.8130 - val_loss: 0.4206
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4011 - val_accuracy: 0.8049 - val_loss: 0.4279
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4002 - val_accuracy: 0.8130 - val_loss: 0.4230
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.3980 - val_accuracy: 0.8130 - val_loss: 0.4251
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.3984 - val_accuracy: 0.8049 - val_loss: 0.4256
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.3963 - val_accuracy: 0.8049 - val_loss: 0.4261
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.3961 - val_accuracy: 0.8130 - val_loss: 0.4252
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8187 - loss: 0.3946 - val_accuracy: 0.8130 - val_loss: 0.4244
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.3937 - val_accuracy: 0.8130 - val_loss: 0.4279
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.3924 - val_accuracy: 0.8130 - val_loss: 0.4258
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8228 - loss: 0.3912 - val_accuracy: 0.8049 - val_loss: 0.4260
#
# Model training complete.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Predict target probabilities
y_pred_probs = ann_pima.predict(X_test_p)
# Threshold probabilities to binary classes (0 or 1)
y_pred_classes = (y_pred_probs >= 0.5).astype(int)

test_acc = accuracy_score(y_test_p, y_pred_classes)
print(f"ANN Holdout Test Accuracy: {test_acc * 100:.2f}%\n")

print("--- Classification Report ---")
print(classification_report(y_test_p, y_pred_classes, target_names=['No Diabetes', 'Diabetes']))

# Plot confusion matrix
cm_pima = confusion_matrix(y_test_p, y_pred_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm_pima, annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.title("ANN Classification Confusion Matrix-24EU02026")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ANN Holdout Test Accuracy: 72.08%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#  No Diabetes       0.77      0.81      0.79       100
#     Diabetes       0.61      0.56      0.58        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.68      0.69       154
# weighted avg       0.72      0.72      0.72       154

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load Sonar dataset
sonar_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"
sonar_features = [f"F_{i}" for i in range(1, 61)]
sonar_columns = sonar_features + ['Class']
sonar_df = pd.read_csv(sonar_url, header=None, names=sonar_columns)

# Encode class: M -> 1, R -> 0
sonar_df['Class_numeric'] = sonar_df['Class'].map({'M': 1, 'R': 0})

X_sonar = sonar_df[sonar_features]
y_sonar = sonar_df['Class_numeric']

# Scale features
scaler_sonar = StandardScaler()
X_sonar_scaled = scaler_sonar.fit_transform(X_sonar)

# Split into train/test sets
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(
    X_sonar_scaled, y_sonar, test_size=0.30, stratify=y_sonar, random_state=42
)

print("Sonar Training Set Shape:", X_train_s.shape)
print("Sonar Test Set Shape:", X_test_s.shape)
# Out:
# Sonar Training Set Shape: (145, 60)
# Sonar Test Set Shape: (63, 60)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Design regularized sequential network
ann_sonar = Sequential([
    # Input layer + Dense hidden layer 1
    Dense(64, activation='relu', input_shape=(60,)),
    Dropout(0.3), # Apply 30% dropout rate to mitigate co-adaptation
    # Dense hidden layer 2
    Dense(32, activation='relu'),
    Dropout(0.3), # Apply 30% dropout rate
    # Binary sigmoid output node
    Dense(1, activation='sigmoid')
])

print("Regularized Sonar ANN Architecture established:")
ann_sonar.summary()
# Out:
# Regularized Sonar ANN Architecture established:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         3,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,017 (23.50 KB)
#  Trainable params: 6,017 (23.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
ann_sonar.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Fit model and collect training metrics
history_sonar = ann_sonar.fit(
    X_train_s,
    y_train_s,
    epochs=80,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)

print("\nModel training complete.")
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5259 - loss: 0.7668 - val_accuracy: 0.5517 - val_loss: 0.6613
# Epoch 2/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5431 - loss: 0.6980 - val_accuracy: 0.7586 - val_loss: 0.5909
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6638 - loss: 0.5928 - val_accuracy: 0.7931 - val_loss: 0.5483
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7241 - loss: 0.5690 - val_accuracy: 0.7931 - val_loss: 0.5156
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7414 - loss: 0.5827 - val_accuracy: 0.8276 - val_loss: 0.4941
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7328 - loss: 0.5475 - val_accuracy: 0.7931 - val_loss: 0.4755
# Epoch 7/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7586 - loss: 0.4934 - val_accuracy: 0.8276 - val_loss: 0.4582
# Epoch 8/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8190 - loss: 0.4860 - val_accuracy: 0.8621 - val_loss: 0.4422
# Epoch 9/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8448 - loss: 0.4343 - val_accuracy: 0.8621 - val_loss: 0.4295
# Epoch 10/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8621 - loss: 0.3989 - val_accuracy: 0.8621 - val_loss: 0.4208
# Epoch 11/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7759 - loss: 0.4691 - val_accuracy: 0.8621 - val_loss: 0.4097
# Epoch 12/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8448 - loss: 0.3968 - val_accuracy: 0.8621 - val_loss: 0.3975
# Epoch 13/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8190 - loss: 0.3953 - val_accuracy: 0.8621 - val_loss: 0.3942
# Epoch 14/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8276 - loss: 0.4298 - val_accuracy: 0.8621 - val_loss: 0.3902
# Epoch 15/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8448 - loss: 0.3776 - val_accuracy: 0.8621 - val_loss: 0.3777
# Epoch 16/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8621 - loss: 0.3720 - val_accuracy: 0.8966 - val_loss: 0.3702
# Epoch 17/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9052 - loss: 0.2998 - val_accuracy: 0.8276 - val_loss: 0.3707
# Epoch 18/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9224 - loss: 0.3017 - val_accuracy: 0.8276 - val_loss: 0.3670
# Epoch 19/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8966 - loss: 0.2920 - val_accuracy: 0.8276 - val_loss: 0.3604
# Epoch 20/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9052 - loss: 0.3218 - val_accuracy: 0.8621 - val_loss: 0.3515
# Epoch 21/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9052 - loss: 0.2854 - val_accuracy: 0.8621 - val_loss: 0.3488
# Epoch 22/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9224 - loss: 0.2200 - val_accuracy: 0.8276 - val_loss: 0.3435
# Epoch 23/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9310 - loss: 0.2506 - val_accuracy: 0.8621 - val_loss: 0.3404
# Epoch 24/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8707 - loss: 0.2655 - val_accuracy: 0.8621 - val_loss: 0.3339
# Epoch 25/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9224 - loss: 0.2616 - val_accuracy: 0.8276 - val_loss: 0.3255
# Epoch 26/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9310 - loss: 0.2276 - val_accuracy: 0.8621 - val_loss: 0.3121
# Epoch 27/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9569 - loss: 0.1799 - val_accuracy: 0.8621 - val_loss: 0.3026
# Epoch 28/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9310 - loss: 0.2212 - val_accuracy: 0.8621 - val_loss: 0.3014
# Epoch 29/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9224 - loss: 0.2236 - val_accuracy: 0.8276 - val_loss: 0.3001
# Epoch 30/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8966 - loss: 0.2351 - val_accuracy: 0.8621 - val_loss: 0.3039
# Epoch 31/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9655 - loss: 0.1655 - val_accuracy: 0.8276 - val_loss: 0.3027
# Epoch 32/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9655 - loss: 0.1642 - val_accuracy: 0.8621 - val_loss: 0.3047
# Epoch 33/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9741 - loss: 0.1558 - val_accuracy: 0.8276 - val_loss: 0.3099
# Epoch 34/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9483 - loss: 0.1334 - val_accuracy: 0.8276 - val_loss: 0.3083
# Epoch 35/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9655 - loss: 0.1527 - val_accuracy: 0.8276 - val_loss: 0.3030
# Epoch 36/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9741 - loss: 0.1413 - val_accuracy: 0.8621 - val_loss: 0.2999
# Epoch 37/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9483 - loss: 0.1309 - val_accuracy: 0.8276 - val_loss: 0.3023
# Epoch 38/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.1317 - val_accuracy: 0.7931 - val_loss: 0.3094
# Epoch 39/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9828 - loss: 0.0971 - val_accuracy: 0.7931 - val_loss: 0.3161
# Epoch 40/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.1194 - val_accuracy: 0.7931 - val_loss: 0.3147
# Epoch 41/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0920 - val_accuracy: 0.7931 - val_loss: 0.3129
# Epoch 42/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9569 - loss: 0.1204 - val_accuracy: 0.7931 - val_loss: 0.3058
# Epoch 43/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9741 - loss: 0.0852 - val_accuracy: 0.8276 - val_loss: 0.2970
# Epoch 44/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0978 - val_accuracy: 0.8276 - val_loss: 0.2924
# Epoch 45/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0897 - val_accuracy: 0.8621 - val_loss: 0.2807
# Epoch 46/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0772 - val_accuracy: 0.8621 - val_loss: 0.2806
# Epoch 47/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9569 - loss: 0.1115 - val_accuracy: 0.8276 - val_loss: 0.2946
# Epoch 48/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9741 - loss: 0.0991 - val_accuracy: 0.8276 - val_loss: 0.3122
# Epoch 49/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9828 - loss: 0.0704 - val_accuracy: 0.8276 - val_loss: 0.3292
# Epoch 50/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0791 - val_accuracy: 0.7931 - val_loss: 0.3227
# Epoch 51/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0900 - val_accuracy: 0.8621 - val_loss: 0.3070
# Epoch 52/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0889 - val_accuracy: 0.8621 - val_loss: 0.3059
# Epoch 53/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0785 - val_accuracy: 0.8276 - val_loss: 0.3252
# Epoch 54/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0728 - val_accuracy: 0.8276 - val_loss: 0.3349
# Epoch 55/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0705 - val_accuracy: 0.8276 - val_loss: 0.3409
# Epoch 56/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0486 - val_accuracy: 0.8276 - val_loss: 0.3456
# Epoch 57/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0563 - val_accuracy: 0.8276 - val_loss: 0.3202
# Epoch 58/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0498 - val_accuracy: 0.8276 - val_loss: 0.3166
# Epoch 59/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0852 - val_accuracy: 0.8276 - val_loss: 0.3205
# Epoch 60/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0516 - val_accuracy: 0.8276 - val_loss: 0.3201
# Epoch 61/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0841 - val_accuracy: 0.8621 - val_loss: 0.3255
# Epoch 62/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9655 - loss: 0.0660 - val_accuracy: 0.8621 - val_loss: 0.3487
# Epoch 63/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9655 - loss: 0.0767 - val_accuracy: 0.8621 - val_loss: 0.3552
# Epoch 64/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0592 - val_accuracy: 0.8621 - val_loss: 0.3571
# Epoch 65/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.8621 - val_loss: 0.3615
# Epoch 66/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0416 - val_accuracy: 0.8276 - val_loss: 0.3724
# Epoch 67/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0433 - val_accuracy: 0.8276 - val_loss: 0.3720
# Epoch 68/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 0.8276 - val_loss: 0.3721
# Epoch 69/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.8276 - val_loss: 0.3769
# Epoch 70/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0469 - val_accuracy: 0.8276 - val_loss: 0.3821
# Epoch 71/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0402 - val_accuracy: 0.8621 - val_loss: 0.3807
# Epoch 72/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.8621 - val_loss: 0.3824
# Epoch 73/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0339 - val_accuracy: 0.8621 - val_loss: 0.3866
# Epoch 74/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0332 - val_accuracy: 0.8621 - val_loss: 0.3983
# Epoch 75/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0387 - val_accuracy: 0.8621 - val_loss: 0.3981
# Epoch 76/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.8621 - val_loss: 0.3964
# Epoch 77/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0301 - val_accuracy: 0.8621 - val_loss: 0.3977
# Epoch 78/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.8621 - val_loss: 0.4035
# Epoch 79/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0550 - val_accuracy: 0.8621 - val_loss: 0.3909
# Epoch 80/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0365 - val_accuracy: 0.8621 - val_loss: 0.3895
#
# Model training complete.

# %%
import matplotlib.pyplot as plt

# Extract metrics from training history
train_loss = history_sonar.history['loss']
val_loss = history_sonar.history['val_loss']
train_acc = history_sonar.history['accuracy']
val_acc = history_sonar.history['val_accuracy']
epochs_range = range(1, len(train_loss) + 1)

# Plot loss curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(epochs_range, train_loss, 'b-', label='Training Loss')
axes[0].plot(epochs_range, val_loss, 'r-', label='Validation Loss')
axes[0].set_title("Training vs. Validation Loss-24EU02026")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")
axes[0].legend()

# Plot accuracy curves
axes[1].plot(epochs_range, train_acc, 'b-', label='Training Accuracy')
axes[1].plot(epochs_range, val_acc, 'r-', label='Validation Accuracy')
axes[1].set_title("Training vs. Validation Accuracy-24EU02026")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities on test set
sonar_probs = ann_sonar.predict(X_test_s)[:, 0]
sonar_preds = (sonar_probs >= 0.5).astype(int)

# Print classification report
print("--- Classification Report (Sonar Test Set) ---")
print(classification_report(y_test_s, sonar_preds, target_names=['Rock (0)', 'Mine (1)']))

# Compute ROC curve coordinates and AUC score
fpr, tpr, _ = roc_curve(y_test_s, sonar_probs)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(6, 4.5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title("ROC Curve: Sonar Classification-24EU02026")
plt.xlabel("False Positive Rate (1 - Specificity)")
plt.ylabel("True Positive Rate (Sensitivity)")
plt.legend(loc="lower right")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# --- Classification Report (Sonar Test Set) ---
#               precision    recall  f1-score   support
#
#     Rock (0)       0.79      0.90      0.84        29
#     Mine (1)       0.90      0.79      0.84        34
#
#     accuracy                           0.84        63
#    macro avg       0.84      0.85      0.84        63
# weighted avg       0.85      0.84      0.84        63

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define parameterized builder function
def build_ann_model(optimizer_name='adam'):
    model = Sequential([
        Dense(32, activation='relu', input_shape=(8,)),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=optimizer_name,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

print("Modular ANN model builder function established.")
# Out:
# Modular ANN model builder function established.

# %%
optimizers = ['adam', 'sgd', 'rmsprop']
history_records = {}

print("--- Running Optimizer Search ---")
for opt in optimizers:
    print(f"Training network using: {opt}...")
    temp_model = build_ann_model(optimizer_name=opt)

    # Fit for 30 epochs
    hist = temp_model.fit(
        X_train_p,
        y_train_p,
        validation_split=0.2,
        epochs=30,
        batch_size=16,
        verbose=0
    )
    history_records[opt] = hist.history['loss']

print("Tuning loop complete.")
# Out:
# --- Running Optimizer Search ---
# Training network using: adam...
# Training network using: sgd...
# Training network using: rmsprop...
# Tuning loop complete.

# %%
import matplotlib.pyplot as plt

# Plot optimizer training loss profiles
plt.figure(figsize=(7, 4.5))
for opt in optimizers:
    plt.plot(range(1, 31), history_records[opt], label=f"Optimizer: {opt.upper()}")

plt.title("Training Loss Convergence Comparison-24EU02026")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Configure EarlyStopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Build model with the optimal optimizer found
tuned_model = build_ann_model(optimizer_name='adam')

print("Training model with Early Stopping...")
# Fit model for up to 100 epochs
history_tuned = tuned_model.fit(
    X_train_p,
    y_train_p,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Training model with Early Stopping...
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6232 - loss: 0.6768 - val_accuracy: 0.6341 - val_loss: 0.6347
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7026 - loss: 0.5780 - val_accuracy: 0.7073 - val_loss: 0.5508
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7189 - loss: 0.5219 - val_accuracy: 0.6992 - val_loss: 0.5035
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7658 - loss: 0.4848 - val_accuracy: 0.7236 - val_loss: 0.4774
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7739 - loss: 0.4633 - val_accuracy: 0.7561 - val_loss: 0.4621
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7760 - loss: 0.4501 - val_accuracy: 0.7805 - val_loss: 0.4543
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7882 - loss: 0.4414 - val_accuracy: 0.7805 - val_loss: 0.4495
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7882 - loss: 0.4367 - val_accuracy: 0.7967 - val_loss: 0.4445
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7943 - loss: 0.4292 - val_accuracy: 0.7967 - val_loss: 0.4484
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7963 - loss: 0.4250 - val_accuracy: 0.7967 - val_loss: 0.4441
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.4224 - val_accuracy: 0.7967 - val_loss: 0.4425
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4181 - val_accuracy: 0.8130 - val_loss: 0.4411
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4154 - val_accuracy: 0.8130 - val_loss: 0.4445
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4126 - val_accuracy: 0.8130 - val_loss: 0.4409
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4100 - val_accuracy: 0.8130 - val_loss: 0.4441
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.4078 - val_accuracy: 0.8049 - val_loss: 0.4453
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4048 - val_accuracy: 0.8130 - val_loss: 0.4417
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.4047 - val_accuracy: 0.8130 - val_loss: 0.4441
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4027 - val_accuracy: 0.7886 - val_loss: 0.4452
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.3987 - val_accuracy: 0.7967 - val_loss: 0.4458
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.3971 - val_accuracy: 0.8049 - val_loss: 0.4384
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.3961 - val_accuracy: 0.7967 - val_loss: 0.4460
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8106 - loss: 0.3945 - val_accuracy: 0.7886 - val_loss: 0.4457
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.3908 - val_accuracy: 0.7886 - val_loss: 0.4413
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8045 - loss: 0.3901 - val_accuracy: 0.7886 - val_loss: 0.4427
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8106 - loss: 0.3876 - val_accuracy: 0.7724 - val_loss: 0.4427
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.3865 - val_accuracy: 0.7886 - val_loss: 0.4420
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8086 - loss: 0.3858 - val_accuracy: 0.7805 - val_loss: 0.4446
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8187 - loss: 0.3826 - val_accuracy: 0.7886 - val_loss: 0.4423
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.3830 - val_accuracy: 0.7886 - val_loss: 0.4468
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8208 - loss: 0.3822 - val_accuracy: 0.7886 - val_loss: 0.4442
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %%
from sklearn.metrics import accuracy_score

# Evaluate baseline model from Task 1
baseline_accuracy = ann_pima.evaluate(X_test_p, y_test_p, verbose=0)[1]

# Evaluate the tuned, early-stopped model
tuned_accuracy = tuned_model.evaluate(X_test_p, y_test_p, verbose=0)[1]

comparison_df = pd.DataFrame({
    'Model Configuration': ['Baseline ANN (Fixed 50 Epochs)', 'Tuned ANN (with Early Stopping)'],
    'Test Accuracy (%)': [baseline_accuracy * 100, tuned_accuracy * 100],
    'Epochs Trained': [50, len(history_tuned.history['loss'])]
})

print("--- Final Performance Comparison ---")
print(comparison_df.to_string(index=False))
# Out:
# --- Final Performance Comparison ---
#             Model Configuration  Test Accuracy (%)  Epochs Trained
#  Baseline ANN (Fixed 50 Epochs)          72.077924              50
# Tuned ANN (with Early Stopping)          75.324672              31
